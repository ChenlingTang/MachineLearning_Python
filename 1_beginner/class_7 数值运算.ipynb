# %% [markdown]
# # Python 数值运算

# %%
1+1
# Out:
# 2

# %%
print(1+1)
print(3-1)
# Out:
# 2
# 2

# %%
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# #### % 求余

# %%
10%3
# Out:
# 1

# %% [markdown]
# #### ** 次方

# %%
2**4
# Out:
# 16

# %% [markdown]
# ## type() 打印类型
#
# #### int 整数（除小数）
# #### float 小数
# #### str 字符串
# #### bool Yes/No
#
# ##### 包含字符的的字符串，不可转换成数字

# %%
tang = 5 - 3
2<= tang <5
# Out:
# True

# %% [markdown]
# ## 运算顺序
#
# ### （）
# ### 【**】
# ### * / %
# ### + -

# %% [markdown]
# ### abs()
# ### round()
# ### min()
# ### max()

# %% [markdown]
# ## 科学计数法

# %%
1e10
# Out:
# 10000000000.0

# %%
1e-4
# Out:
# 0.0001
